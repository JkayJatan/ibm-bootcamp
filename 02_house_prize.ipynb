# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data={
    "Area(sq ft)":[1000,1500,1800,2400,3000,3500,4000,4500],
    "Price($ millions)":[50,70,85,110,150,175,200,220]
}
df=pd.DataFrame(data)

# %%
print("Dataset:")
df
# Out:
# Dataset:
#    Area(sq ft  Price($ millions)
# 0        1000                 50
# 1        1500                 70
# 2        1800                 85
# 3        2400                110
# 4        3000                150
# 5        3500                175
# 6        4000                200
# 7        4500                220

# %%
x=df[["Area(sq ft"]]
y=df["Price($ millions)"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_train)

# %%
print("\n Model Trained Succesfully!")
print("predicted prices:",y_pred)
print("Actual prices:",y_test.values)
# Out:
#  Model Trained Succesfully!
# predicted prices: [ 46.63276944 221.69929671  86.64797567 146.67078502 116.65938035
#  196.68979282]
# Actual prices: [ 70 175]

# %%
plt.scatter(x,y,color="blue",label="Actual Data")
plt.plot(x,model.predict(x,color="red"))
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 plt.scatter(x,y,color="blue",label="Actual Data")
# ----> 2 plt.plot(x,model.predict(x,colour="red"))
#       3 plt.legend()
#       4 plt.show()
#
# TypeError: LinearModel.predict() got an unexpected keyword argument 'colour'

# %%
new_area=[[2800]]
predicted_price=model.predict(new_area)
print(f"\n Predicted Price for 2800 sq ft ${predicted_price[0]:.2f} millions")
